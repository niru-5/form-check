# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio
import os

# %%
data_folder = '/hdd/side_projects/imu_project/form-check/data_acquisition/data'

# list all csv files in the data folder
csv_files = sorted([f for f in os.listdir(data_folder) if f.endswith('.csv')])

# load the first csv file
print (csv_files)
# Out:
# ['accelerometer-20250316-143249.csv', 'accelerometer-20250316-143510.csv', 'accelerometer-20250316-144335.csv', 'gyroscope-20250316-143249.csv', 'gyroscope-20250316-143510.csv', 'gyroscope-20250316-144335.csv', 'magnetometer-20250316-143249.csv', 'magnetometer-20250316-143510.csv', 'magnetometer-20250316-144335.csv']

# %%
acc_df = pd.read_csv(os.path.join(data_folder, csv_files[2]))
print (acc_df.head())

# plot the acceleration data
plt.figure(figsize=(10, 5))
plt.plot(acc_df['epoch'], acc_df['x'], label='X')
plt.plot(acc_df['epoch'], acc_df['y'], label='Y')
plt.plot(acc_df['epoch'], acc_df['z'], label='Z')
plt.legend()
plt.show()

# plot the gyroscope data
# Out:
#            epoch         x         y         z
# 0  1742132615704  0.339355  0.750000  0.611328
# 1  1742132615714  0.353027  0.740234  0.618164
# 2  1742132615724  0.381836  0.728027  0.619141
# 3  1742132615733  0.393555  0.702148  0.640625
# 4  1742132615743  0.414062  0.708008  0.637207
